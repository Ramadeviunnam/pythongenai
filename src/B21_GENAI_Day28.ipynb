# %%
import PyPDF2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import PyPDF2
#
# ModuleNotFoundError: No module named 'PyPDF2'

# %%
pip install PyPDF2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
5
# Out:
# 5

# %%
import nltk

# %%
import PyPDF2

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
files = [r"D:\lenin\Practise_SF\B21\B21_NOTES\B21_GENAI_Day28\Employee_Attendance_Policy.pdf",
        r"D:\lenin\Practise_SF\B21\B21_NOTES\B21_GENAI_Day28\Employee_Conduct_Policy.pdf",
        r"D:\lenin\Practise_SF\B21\B21_NOTES\B21_GENAI_Day28\HR_Policy_Document.pdf",
        r"D:\lenin\Practise_SF\B21\B21_NOTES\B21_GENAI_Day28\IT_Security_Policy.pdf",
        r"D:\lenin\Practise_SF\B21\B21_NOTES\B21_GENAI_Day28\Workplace_Safety_Policy.pdf"]

# %%
documents=[]#li=[]#li.append()

# %%
for file in files:
    reader=PyPDF2.PdfReader(file)
    text=""
    for page in reader.pages:
        text+=page.extract_text()
    documents.append(text)

# %%
print("Doucuments loaded:",len(documents))
# Out:
# Doucuments loaded: 5

# %%
query=input("Ask Question:")
# Out:
# Ask Question: leave policy

# %%
from nltk.tokenize import word_tokenize
query_tokens = word_tokenize(query)

# %%
print("Query tokens:", query_tokens)
# Out:
# Query tokens: ['leave', 'policy']

# %%
for doc in documents:
    tokens=word_tokenize(doc)
    common=set(tokens).intersection(set(query_tokens))

# %%
    print("Common Tokens:", common)
# Out:
# Common Tokens: {'policy'}

# %%
if len(common)>0:
    print("\nRelevant Section\n")
    print(doc[:500])
# Out:
# Relevant Section
#
# WORKPLACE SAFETY POLICY
# 1. Purpose
# The purpose of this Workplace Safety Policy is to ensure a safe, healthy, and secure
# working environment for all employees, contractors, visitors, and stakeholders. The
# Company is committed to preventing workplace injuries, illnesses, accidents, and unsafe
# conditions.
#
# 2. Scope
# This policy applies to:
#  All full -time, part -time, and contractual employees
#  Interns, consultants, and temporary staff
#  Visitors and vendors on company premises

# %%
#Bag of words Matching
