# %%
#cosaine similarity -- metric 
#

# %%
text_vijay = "Vijay became Chief Minister after winning the political election"
text_election = "Vijay says Modi had no political interferences in the election outcome. He says it was a witchhunt by political parties. He claimed Modi is a friend who had nothing to do with the election"
text_modi = "Post election, Modi became the Prime Minister of India. Modi had serverd as the Cheif Minister of Gurajat earlier"

# %%
documents = [text_vijay, text_election, text_modi]

# %%
#CountVectorizer or TfidVectorizer

# %%
import pandas as pd

# %%
from sklearn.features_extraction.text import CountVectorizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from sklearn.features_extraction.text import CountVectorizer
#
# ModuleNotFoundError: No module named 'sklearn.features_extraction'

# %%
pip install CountVecotorizer
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement CountVecotorizer (from versions: none)
# ERROR: No matching distribution found for CountVecotorizer

# %%
pip install sklearn
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [15 lines of output]
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#     it would be great if you take some time to track which package uses
# ...

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install scikit-learn
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\anaconda3
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2026.3.19  |       haa95532_0         126 KB
#     certifi-2026.4.22          |  py313haa95532_0         133 KB
#     conda-26.1.1               |  py313haa95532_0         1.2 MB
#     openssl-3.5.6              |       hbb43b14_0         8.9 MB
#     scikit-learn-1.7.2         |  py313h7f7e138_1         8.5 MB
#     ------------------------------------------------------------
#                                            Total:        18.9 MB
#
# The following packages will be UPDATED:
#
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
#count_vectorizer = CountVectorizer(stop_words='english')

# %%
texts = ["I love AI","I love Python"]
count_vectorizer = CountVectorizer()

# %%
X = count_vectorizer.fit_transform(texts) # it's a combination of 2 things, 1 - fit -learning from data
# 2 - tranform - applying that learning

# %%
print(count_vectorizer.get_feature_names_out())
print(X.toarray())
# Out:
# ['ai' 'love' 'python']
# [[1 1 0]
#  [0 1 1]]

# %%
count_vectorizer = CountVectorizer(stop_words='english')

# %%
count_vectorizer = CountVectorizer()

# %%
_matrix = count_vectorizer.fit_transform(documents)
term_matrix = _matrix.todense()

# %%
df = pd.DataFrame(term_matrix, 
                  columns=count_vectorizer.get_feature_names_out(),
                  index=[text_vijay, text_election, text_modi])

# %%
df
# Out:
#                                                     after  as  became  by  \
# Vijay became Chief Minister after winning the p...      1   0       1   0
# Vijay says Modi had no political interferences ...      0   0       0   1
# Post election, Modi became the Prime Minister o...      0   1       1   0
#
#                                                     cheif  chief  claimed  do  \
# Vijay became Chief Minister after winning the p...      0      1        0   0
# Vijay says Modi had no political interferences ...      0      0        1   1
# Post election, Modi became the Prime Minister o...      1      0        0   0
#
#                                                     earlier  election  ...  \
# Vijay became Chief Minister after winning the p...        0         1  ...
# Vijay says Modi had no political interferences ...        0         2  ...
# Post election, Modi became the Prime Minister o...        1         1  ...
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
print(cosine_similarity(df,df))
# Out:
# [[1.         0.34403123 0.38490018]
#  [0.34403123 1.         0.34050261]
#  [0.38490018 0.34050261 1.        ]]
